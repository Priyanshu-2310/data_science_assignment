# %% [markdown]
# # Control Statement Assignement

# %% [markdown]
# Question 1 : Check the given number is divisible by 5 or not?

# %%
num = int(input("Enter your number = "))
if(num % 5 == 0):
    print("Number is divisible by 5")
else:
    print("Number is not divisible by 5")
# Out:
# Enter your number =  21
# Number is not divisible by 5

# %% [markdown]
# Question 2 : Find maximum number in given three numbers

# %%
num1 = int(input("Enter your first number = "))
num2 = int(input("Enter your second number = "))
num3 = int(input("Enter your third number = "))

if(num1 > num2 and num1 > num3):
    print('number 1 is greater')

elif(num2 > num1 and num2 > num3):
    print("number 2 is greatest")

elif(num3 > num1 and num3 > num2):
    print("number 3 is greatest")

# %% [markdown]
# Question 3 –
# A toy vendor supplies three types of toys:
# Battery Based Toys, Key-based Toys, and Electrical Charging Based Toys.
#
# The vendor gives a discount of 10% on orders for battery-based toys if the order is for more than Rs. 1000.
# On orders of more than Rs. 100 for key-based toys, a discount of 5% is given,
# and a discount of 10% is given on orders for electrical charging based toys of value more than Rs. 500.
#
# Assume that the numeric codes 1, 2, and 3 are used for battery based toys, key-based toys, and electrical charging based toys respectively.
#
# Write a program that reads the product code and the order amount and prints out the net amount that the customer is required to pay after the discount.

# %%
print("Enter 1 for Battery Based Toys ")
print("Enter 2 for key Based Toys ")
print("Enter 3 for Electical Charging Based Toys")

val = int(input("Enter the number = "))

if(val == 1):
    print("You choose Battery Based Toys")
    order = int(input("Enter the amount = "))
    if(order >= 1000):
        amount = order * 10 /100
        realamount = order - amount
        print("You will have to pay amount after 10 % = ", realamount)
    else:
        print("Your order is less than 1000 so no discount is avalible you will have to pay = ", order)

elif(val == 2):
    print("You choose Key-Based Toys")
    order = int(input("Enter the amount = "))
    if(order >= 100):
        amount = order * 5 /100
        realamount = order - amount
        print("You will have to pay amount after 10 % = ", realamount)
    else:
        print("Your order is less than 500 so no discount is avalible you will have to pay = ", order)

elif(val == 3):
    print("You choose Electical-Charging Toys")
    order = int(input("Enter the amount = "))
    if(order >= 500):
        amount = order * 10 /100
        realamount = order - amount
        print("You will have to pay amount after 10 % = ", realamount)
    else:
        print("Your order is less than 500 so no discount is avalible you will have to pay = ", order)

else:
    print("You enter wrong key")
# Out:
# Enter 1 for Battery Based Toys
# Enter 2 for key Based Toys
# Enter 3 for Electical Charging Based Toys
# Enter the number =  1
# You choose Battery Based Toys
# Enter the amount =  1000
# You will have to pay amount after 10 % =  900.0
